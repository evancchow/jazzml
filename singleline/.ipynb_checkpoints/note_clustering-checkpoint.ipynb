# %% [markdown]
# In this iPython notebook, you'll cluster notes based on offset and pitch. In this note book, you actually generate the notes Takes a single stream of notes representing a melody.

# %%
from collections import Counter, defaultdict
from itertools import izip_longest
from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
import pandas as pd
import numpy as np
import sys
sys.path.append('C:/Python27/Lib/site-packages')

# %%
# Import and order the original notes.
alice = pd.read_csv('alicenotes.txt', skiprows=2)[:].sort("Offset")
alice.index = xrange(1, len(alice) + 1)
alice = alice[alice.Octave >= 4] # threshold >= octave 4 for melodies
with open('alicenotes.txt', 'rb') as f:
    metmark = float(f.readline())
    tsig_num, tsig_den = [i for i in f.readline().replace(' /', '').split()]
    
print "Metrics:" 
print metmark, tsig_num, tsig_den, len(alice) # len shorter if octave cutoff, also if [:200] in .read_csv
alice.head(20)
# Out:
# Metrics:
# 145.0 3 4 377
#    Note/Rest  Octave       Len     Offset
# 1          G       5  2.625000   0.000000
# 2          C       4  2.000000   0.125000
# 3          G       4  0.875000   1.000000
# 4         E-       5  0.333333   3.125000
# 7          E       5  0.750000   3.375000
# 10         C       5  0.250000   8.625000
# 14         D       4  1.000000  12.000000
# 16         E       4  0.125000  13.000000
# 17         F       4  0.750000  14.000000
# 20         E       4  0.125000  15.000000
# 21         G       5  0.375000  15.625000
# 22         D       4  1.000000  16.000000
# 23         G       4  0.500000  16.000000
# 25         C       5  0.250000  16.666667
# 26         G       5  0.125000  17.125000
# 27         C       6  0.125000  17.500000
# 28         E       6  0.250000  17.750000
# 29         G       6  0.750000  18.125000
# 31         E       6  0.125000  19.000000
# 32         C       6  0.625000  19.666667
#
# [20 rows x 4 columns]

# %% [markdown]
# Now, let's code some functions for generating the notes and the rhythm (offsets).

# %%
""" 1. Get generated notes based on the trigram model. """

# Iterate over a list in chunks of size n. Return tuples (for dict).
def chunks(iterable, n):
    for ix, item in enumerate(iterable):
        if ix == len(iterable) - (n-1): return
        yield tuple(iterable[ix:ix+n])

# Build the conditional probability tables.
def condProbTables(ngramfreqs, nngramfreqs):
    nprobs = defaultdict(int)
    prevnngramnexts = defaultdict(list)
    for ngram, freq in ngramfreqs.items():
        prevnngram = ngram[:-1]
        currchar = ngram[-1]
        nprobs[(currchar, prevnngram)] = float(ngramfreqs[ngram]) / nngramfreqs[prevnngram]
        if prevnngram not in prevnngramnexts.keys():
            prevnngramnexts[prevnngram].extend([(currchar, (float(ngramfreqs[ngram]) / nngramfreqs[prevnngram]))])
            continue
        prevnngramnexts[prevnngram].extend([(currchar, (float(ngramfreqs[ngram]) / nngramfreqs[prevnngram]))])
    return nprobs, prevnngramnexts
    
# Yield the next note for a given n-gram model.
# 'unitsize' is n, i.e. 3 for using trigrams.
# args are the previous notes used to generate the next one.
# Assumes # of args == same # for lookup in prevnnnexts
def yieldNext(prevnnexts, *args):
    lookup = tuple([a for a in args])
    nexts = np.array(prevnnexts[lookup])
    nextnotes = nexts[:,0]
    probabilities = nexts[:,1]
    return np.random.choice(nextnotes, p=probabilities)

# Generate 100 trigrams.
def genTrigrams(prevbigramnexts):
    note1 = "start"
    note2 = "start"
    note3 = note2
    for i in xrange(100):
        note3 = yieldNext(prevbigramnexts, note1, note2)
        note1 = note2
        note2 = note3
        print note1, note2, note3
        yield note3
        
""" 2. Generate the offsets using simple frequency probabilities. """

# Iterate over iterable in groups of n.
def grouper(n, iterable, fillvalue=None):
    for ix, i in enumerate(iterable):
        if ix == len(iterable) - 1:
            break
        yield (iterable[ix], iterable[ix+1])
        
# Normalize an iterable.
def normList(L, normalizeTo=1):
    vMax = sum(L)
    return [ x/(vMax*1.0)*normalizeTo for x in L]

# Round to nearest nth of a unit.
def my_round(x, n=4):
    return round(x*n)/n

# %%
""" The script to generate the notes."""

# Iterates over rows, where each element in the iterable is twofold: 
# element[0] = the index, element[1] = the note object
possiblenotes = ["%s%s" % (row[1]["Note/Rest"], row[1]["Octave"]) for row in alice.iterrows()]
possiblenotes.insert(0, "start")
possiblenotes.insert(0, "start")
possiblenotes.insert(0, "start")

# Get trigram probabilities.
bigramfreqs = defaultdict(int)
for i in chunks(possiblenotes, 2):
    bigramfreqs[i] += 1
trigramfreqs = defaultdict(int)
for i in chunks(possiblenotes, 3):
    trigramfreqs[i] += 1
    
# encode trigram probabilities
triprobs, prevbigramnexts = condProbTables(trigramfreqs, bigramfreqs)

""" The offsets. """

offsets = defaultdict(int)
genTuples = grouper(2, [float(i) for i in alice["Offset"]])
for j in genTuples:
    toCompare = j
    diff = float(toCompare[1]) - float(toCompare[0])
    diff = my_round(diff)
    if diff > 4: continue # can't have gaps > 4
    offsets[diff] += 1 # set gaps nicely, only integer gaps.
    
offset_poss = [k for k in offsets]           # possible offsets. need separate for np.random.choice()
offset_probs = [offsets[k] for k in offsets] # probabilities for each of those offset

# prune offsets after normalizing so # possible offsets < 32 for np.random.choice()
# durations: cutoff if over 6
offset_ixToDel = [jx for jx, j in enumerate(offset_probs) if j < 5 and (offset_poss[jx] < 2)]
offset_poss = [i for ix, i in enumerate(offset_poss) if ix not in offset_ixToDel]
offset_probs = [j for jx, j in enumerate(offset_probs) if jx not in offset_ixToDel]

for jx, j in enumerate(offset_poss):
    if j <= 0:
        del offset_poss[jx]
        del offset_probs[jx]
offset_probs = normList(offset_probs)

# Assert
print sum(offset_probs)
print len(offset_poss), len(offset_probs)
for i, j in zip(offset_poss, offset_probs):
    print "%s: %s" % (i, j)
    
# Try-except to deal with reruning cell. Cheap fix.
try: 
    gennotes = list(note for note in genTrigrams(prevbigramnexts) if note != "start")
    genoffsets = list(np.random.choice(offset_poss, p=offset_probs) for i in xrange(len(gennotes)))
except IndexError: 
    gennotes = list(note for note in genTrigrams(prevbigramnexts) if note != "start")
    genoffsets = list(np.random.choice(offset_poss, p=offset_probs) for i in xrange(len(gennotes)))

# Assert that you've successfully generated the notes (trigram model) and their durations.
# write to file, one note per line.
with open('alicetrigrams.txt', 'wb') as f:
    for note, duration in zip(gennotes, genoffsets):
        f.write("%s,%s\n" % (note, duration))
# Out:
# 1.0
# 15 15
# 0.25: 0.287822878229
# 1.0: 0.121771217712
# 2.0: 0.0258302583026
# 3.0: 0.0110701107011
# 4.0: 0.00369003690037
# 0.75: 0.121771217712
# 3.25: 0.0110701107011
# 2.75: 0.00738007380074
# 2.5: 0.029520295203
# 1.25: 0.070110701107
# 1.75: 0.0479704797048
# 3.5: 0.00738007380074
# 1.5: 0.0848708487085
# 2.25: 0.0184501845018
# 0.5: 0.151291512915
# start start start
# start G5 G5
# G5 C4 C4
# C4 F4 F4
# F4 C#4 C#4
# C#4 C5 C5
# C5 C5 C5
# C5 C4 C4
# C4 D4 D4
# D4 E5 E5
# E5 C4 C4
# C4 E4 E4
# E4 C4 C4
# C4 C4 C4
# C4 E-5 E-5
# E-5 C4 C4
# C4 C4 C4
# C4 G5 G5
# G5 E-5 E-5
# E-5 G#4 G#4
# G#4 C4 C4
# C4 C4 C4
# C4 F4 F4
# F4 C#4 C#4
# C#4 F4 F4
# F4 C#6 C#6
# C#6 D6 D6
# D6 C4 C4
# C4 B6 B6
# B6 E6 E6
# E6 C4 C4
# C4 D6 D6
# D6 E6 E6
# E6 D6 D6
# D6 F6 F6
# F6 E6 E6
# E6 G5 G5
# G5 E-4 E-4
# E-4 G6 G6
# G6 D4 D4
# D4 G5 G5
# G5 C#5 C#5
# C#5 E5 E5
# E5 D6 D6
# D6 C4 C4
# C4 B6 B6
# B6 F4 F4
# F4 G6 G6
# G6 G5 G5
# G5 G4 G4
# G4 E4 E4
# E4 C#4 C#4
# C#4 F#4 F#4
# F#4 C#4 C#4
# C#4 C#5 C#5
# C#5 C4 C4
# C4 C#4 C#4
# C#4 F5 F5
# F5 F4 F4
# F4 F#5 F#5
# F#5 C6 C6
# C6 F4 F4
# F4 C#4 C#4
# C#4 F4 F4
# F4 C#6 C#6
# C#6 D6 D6
# D6 C4 C4
# C4 B6 B6
# B6 F4 F4
# F4 G6 G6
# G6 G5 G5
# G5 G4 G4
# G4 E4 E4
# E4 F5 F5
# F5 E5 E5
# E5 G4 G4
# G4 C5 C5
# C5 G4 G4
# G4 D4 D4
# D4 C5 C5
# C5 E5 E5
# E5 D5 D5
# D5 C5 C5
# C5 G5 G5
# G5 G4 G4
# G4 A4 A4
# A4 B4 B4
# B4 C5 C5
# C5 C5 C5
# C5 D4 D4
# D4 D5 D5
# D5 E5 E5
# E5 D5 D5
# D5 F4 F4
# F4 D4 D4
# D4 D5 D5
# D5 C4 C4
# C4 A4 A4
# A4 D5 D5
# D5 F#4 F#4
