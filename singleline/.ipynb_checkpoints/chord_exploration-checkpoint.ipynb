# %% [markdown]
# In this notebook you'll read in the chordal data for exploration, and generate a chord bank.

# %%
from collections import Counter, defaultdict
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
import sys
sys.path.append('C:/Python27/Lib/site-packages')

# %%
# Import and order rows.
alice = pd.read_csv('alice.txt', skiprows=2)[:].sort("Offset")
alice.index = xrange(1, len(alice) + 1)
# alice = alice[alice.Octave < 4] # threshold >= octave 4 for melodies
with open('alice.txt', 'rb') as f:
    metmark = float(f.readline())
    tsig_num, tsig_den = [i for i in f.readline().replace(' /', '').split()]
    
print "Metrics:"
print metmark, tsig_num, tsig_den, len(alice)
alice.sort(columns="Offset", ascending=True)
alice.head(30)
# Out:
# Metrics:
# 145.0 3 4 583
#    Note/Rest  Octave       Len     Offset
# 1          G       5  2.625000   0.000000
# 2          C       4  2.000000   0.125000
# 3          G       4  0.875000   1.000000
# 4         E-       5  0.333333   3.125000
# 5          F       3  1.250000   3.125000
# 6          B       3  1.333333   3.125000
# 7          E       5  0.750000   3.375000
# 8          G       3  1.625000   6.125000
# 9          C       3  2.000000   6.125000
# 10         C       5  0.250000   8.625000
# 11         F       2  1.875000   9.000000
# 12         C       3  0.125000  11.625000
# 13         B       2  1.875000  12.000000
# 14         D       4  1.000000  12.000000
# 15         A       3  0.750000  12.000000
# 16         E       4  0.125000  13.000000
# 17         F       4  0.750000  14.000000
# 18         B       2  0.250000  14.625000
# 19         E       2  0.125000  14.875000
# 20         E       4  0.125000  15.000000
# 21         G       5  0.375000  15.625000
# 22         D       4  1.000000  16.000000
# 23         G       4  0.500000  16.000000
# 24        G#       3  1.250000  16.000000
# 25         C       5  0.250000  16.666667
# 26         G       5  0.125000  17.125000
# 27         C       6  0.125000  17.500000
# 28         E       6  0.250000  17.750000
# 29         G       6  0.750000  18.125000
# 30         G       3  2.250000  18.125000
#
# [30 rows x 4 columns]
