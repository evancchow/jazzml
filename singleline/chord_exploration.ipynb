# %% [markdown]
# In this notebook you'll read in the chordal data for exploration, and generate a chord bank.

# %%
from collections import Counter, defaultdict
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
import sys
sys.path.append('C:/Python27/Lib/site-packages')

# %%
# Import and order rows.
alice = pd.read_csv('alicechords.txt', skiprows=2)[:].sort("Offset")
alice.index = xrange(1, len(alice) + 1)
# alice = alice[alice.Octave < 4] # threshold >= octave 4 for melodies
with open('alicechords.txt', 'rb') as f:
    metmark = float(f.readline())
    tsig_num, tsig_den = [i for i in f.readline().replace(' /', '').split()]
    
print "Metrics:"
print metmark, tsig_num, tsig_den, len(alice)
alice.sort(columns="Offset", ascending=True)
alice.head(30)
# Out:
# Metrics:
# 145.0 3 4 259
#                                              FullName  \
# 1   Chord {A in octave 3 | D in octave 3} Triple D...
# 2   Chord {G in octave 5 | B in octave 4 | E in oc...
# 3   Chord {F in octave 5 | F in octave 3} Eighth t...
# 4   Chord {B in octave 4 | F in octave 3} Quarter ...
# 5        Chord {B in octave 3 | E in octave 4} Eighth
# 6   Chord {E in octave 5 | B in octave 3 | B in oc...
# 7       Chord {G in octave 4 | B in octave 3} Quarter
# 8          Chord {F in octave 4 | A in octave 3} 32nd
# 9   Chord {E in octave 4 | C in octave 4 | B in oc...
# 10         Chord {C in octave 5 | G in octave 5} 32nd
# 11  Chord {C in octave 5 | C-sharp in octave 4} Ei...
# 12         Chord {A in octave 4 | F in octave 4} 16th
# 13         Chord {C in octave 4 | A in octave 3} 32nd
# 14  Chord {B in octave 3 | F in octave 3} Quarter ...
# 15         Chord {F in octave 3 | D in octave 4} 16th
# 16  Chord {E in octave 5 | D in octave 4 | B in oc...
# ...

# %%
# convert FullName column for column with possible notes
alice['FullName'][5]
# Out:
# 'Chord {B in octave 3 | E in octave 4} Eighth'
